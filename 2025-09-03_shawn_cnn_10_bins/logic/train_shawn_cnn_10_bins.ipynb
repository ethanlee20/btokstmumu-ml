# %% [markdown]
# Setup

# %%
from pathlib import Path
from itertools import product

from torch.nn import MSELoss
import matplotlib as mpl
import matplotlib.pyplot as plt

from btokstmumu_ml_helpers.datasets.constants import Names_of_Levels, Names_of_q_Squared_Vetos, Numbers_of_Events_per_Set
from btokstmumu_ml_helpers.experiment.experiment import CNN_Group
from btokstmumu_ml_helpers.experiment.results_table import Results_Table
from btokstmumu_ml_helpers.experiment.constants import Paths_to_Directories
from btokstmumu_ml_helpers.models.hardware_util import select_device
from btokstmumu_ml_helpers.plot.linearity import plot_linearity

results_table = Results_Table()
device = select_device()

mpl.rcParams["figure.figsize"] = (6, 4)
mpl.rcParams["figure.dpi"] = 400
mpl.rcParams["axes.titlesize"] = 8
mpl.rcParams["figure.titlesize"] = 8
mpl.rcParams["figure.labelsize"] = 30
mpl.rcParams["text.usetex"] = True
mpl.rcParams["text.latex.preamble"] = r"\usepackage{bm}"
mpl.rcParams["font.family"] = "serif"
mpl.rcParams["font.serif"] = ["Computer Modern"]
mpl.rcParams["font.size"] = 8
mpl.rcParams["axes.titley"] = None
mpl.rcParams["axes.titlepad"] = 2
mpl.rcParams["legend.fancybox"] = False
mpl.rcParams["legend.framealpha"] = 0
mpl.rcParams["legend.markerscale"] = 1
mpl.rcParams["legend.fontsize"] = 7.5
# Out:
# Device:  cuda

# %% [markdown]
# CNN

# %%
cnn_group = CNN_Group(
    model_variant="shawn",
    num_sets_per_label={6_000 : 583, 24_000 : 145, 70_000 : 50},
    num_sets_per_label_sensitivity=2_000,
    num_bins_per_dimension=10, #nominal is 10, retrain det_bkg models with 50
    q_squared_veto=Names_of_q_Squared_Vetos().resonances,
    std_scale=True,
    shuffle=True,
    uniform_label_counts=True,
    loss_fn=MSELoss(),
    learning_rate=1e-3, # nominal 3e-4
    learning_rate_scheduler_reduction_factor=0.2, # nominal 0.97
    learning_rate_scheduler_patience=5,
    size_of_training_batch={6_000 : 373, 24_000 : 93, 70_000 : 32},
    size_of_evaluation_batch={6_000 : 373, 24_000 : 93, 70_000 : 32},
    number_of_epochs=50, # nominal 100
    number_of_epochs_between_checkpoints=1,
    results_table=results_table,
    device=device,
    bkg_fraction=0.44,
    bkg_charge_fraction=0.57,
    path_to_common_processed_datasets_dir="../../common/state/data/processed",
    path_to_local_processed_datasets_dir="../state/data",
    path_to_local_models_dir="../state/models"
)

# %%
cnn_group.train_subset(levels=[Names_of_Levels().detector_and_background,], nums_events_per_set=(24_000,), remake_datasets=True)
# Out:
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      170
# costheta_K       760
# chi              760
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Saved tensor of shape: torch.Size([6380, 1, 10, 10, 10]) to ..\state\data\images_det_bkg_q2v_resonances\24000_train_features.pt
# Saved tensor of shape: torch.Size([6380]) to ..\state\data\images_det_bkg_q2v_resonances\24000_train_labels.pt
# Made images dataset.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_val.parquet
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_val.parquet
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Saved tensor of shape: torch.Size([6380, 1, 10, 10, 10]) to ..\state\data\images_det_bkg_q2v_resonances\24000_val_features.pt
# Saved tensor of shape: torch.Size([6380]) to ..\state\data\images_det_bkg_q2v_resonances\24000_val_labels.pt
# Made images dataset.
# Loaded tensor of shape: torch.Size([6380, 1, 10, 10, 10]) from ..\state\data\images_det_bkg_q2v_resonances\24000_train_features.pt
# Loaded tensor of shape: torch.Size([6380]) from ..\state\data\images_det_bkg_q2v_resonances\24000_train_labels.pt
# Loaded tensor of shape: torch.Size([6380, 1, 10, 10, 10]) from ..\state\data\images_det_bkg_q2v_resonances\24000_val_features.pt
# Loaded tensor of shape: torch.Size([6380]) from ..\state\data\images_det_bkg_q2v_resonances\24000_val_labels.pt
#
# Epoch 0 complete:
#     Train loss: 0.7395291768803934
#     Eval loss: 0.16422184456714498
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 1 complete:
#     Train loss: 0.13792963295091842
#     Eval loss: 0.14074395269296688
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 2 complete:
#     Train loss: 0.11385777442889786
#     Eval loss: 0.1163983160604245
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 3 complete:
#     Train loss: 0.093588379743319
#     Eval loss: 0.11700852173963418
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 4 complete:
#     Train loss: 0.0748808988653994
#     Eval loss: 0.11443190278920236
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 5 complete:
#     Train loss: 0.0750927981220165
#     Eval loss: 0.11542563533641101
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 6 complete:
#     Train loss: 0.0645074039972337
#     Eval loss: 0.11469190395479671
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 7 complete:
#     Train loss: 0.05857136793049125
#     Eval loss: 0.11759675931235376
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 8 complete:
#     Train loss: 0.054418016950652875
#     Eval loss: 0.1161669459120081
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 9 complete:
#     Train loss: 0.04947906454605476
#     Eval loss: 0.1652465537178728
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 10 complete:
#     Train loss: 0.056746187548502094
#     Eval loss: 0.18911856735645913
#
# Learning rate: [0.0002]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 11 complete:
#     Train loss: 0.04054026462300874
#     Eval loss: 0.1120091544005512
#
# Learning rate: [0.0002]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 12 complete:
#     Train loss: 0.031058541686679788
#     Eval loss: 0.11812390502245525
#
# Learning rate: [0.0002]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 13 complete:
#     Train loss: 0.03341462495837689
#     Eval loss: 0.11843603022184465
#
# Learning rate: [0.0002]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 14 complete:
#     Train loss: 0.03095200937283311
#     Eval loss: 0.11859507487447428
#
# Learning rate: [0.0002]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 15 complete:
#     Train loss: 0.03000498668231589
#     Eval loss: 0.11802835686050361
#
# Learning rate: [0.0002]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 16 complete:
#     Train loss: 0.03186208505558667
#     Eval loss: 0.12339933392003705
#
# Learning rate: [0.0002]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 17 complete:
#     Train loss: 0.028754277586995725
#     Eval loss: 0.12284886024914429
#
# Learning rate: [4e-05]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 18 complete:
#     Train loss: 0.024273427753768652
#     Eval loss: 0.11612802688464749
#
# Learning rate: [4e-05]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 19 complete:
#     Train loss: 0.023502252878849272
#     Eval loss: 0.11931484181796695
#
# Learning rate: [4e-05]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 20 complete:
#     Train loss: 0.02382000942293532
#     Eval loss: 0.11437658651517164
#
# Learning rate: [4e-05]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 21 complete:
#     Train loss: 0.02317963813972519
#     Eval loss: 0.11501941956158447
#
# Learning rate: [4e-05]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 22 complete:
#     Train loss: 0.02518034860907168
#     Eval loss: 0.11790740512758546
#
# Learning rate: [4e-05]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 23 complete:
#     Train loss: 0.023555003990662387
#     Eval loss: 0.11531965356321745
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 24 complete:
#     Train loss: 0.02269538896281312
#     Eval loss: 0.11753410997661326
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 25 complete:
#     Train loss: 0.022041585153527606
#     Eval loss: 0.11584507453825924
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 26 complete:
#     Train loss: 0.022752636706105896
#     Eval loss: 0.11610164094585496
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 27 complete:
#     Train loss: 0.02239296470469688
#     Eval loss: 0.1167568519144167
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 28 complete:
#     Train loss: 0.023137929297090687
#     Eval loss: 0.11607882472146945
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 29 complete:
#     Train loss: 0.020624084604869676
#     Eval loss: 0.11866546938943484
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 30 complete:
#     Train loss: 0.02155949972829742
#     Eval loss: 0.11779512214145027
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 31 complete:
#     Train loss: 0.02400238565737147
#     Eval loss: 0.11637516221992909
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 32 complete:
#     Train loss: 0.021170088779160847
#     Eval loss: 0.11685216238966765
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 33 complete:
#     Train loss: 0.02231506164870175
#     Eval loss: 0.11634919720740036
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 34 complete:
#     Train loss: 0.021587404913858382
#     Eval loss: 0.11559356803380859
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 35 complete:
#     Train loss: 0.0217160723225656
#     Eval loss: 0.11615151397274598
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 36 complete:
#     Train loss: 0.02389559860429362
#     Eval loss: 0.11522465989368522
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 37 complete:
#     Train loss: 0.023877841058455022
#     Eval loss: 0.11847149123420489
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 38 complete:
#     Train loss: 0.021074621332648747
#     Eval loss: 0.11760892292420877
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 39 complete:
#     Train loss: 0.020351230038855552
#     Eval loss: 0.11615133488729583
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 40 complete:
#     Train loss: 0.020202764372221453
#     Eval loss: 0.11831302434150573
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 41 complete:
#     Train loss: 0.022998192773474556
#     Eval loss: 0.11674096541121956
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 42 complete:
#     Train loss: 0.022100177751901286
#     Eval loss: 0.11867315374146674
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 43 complete:
#     Train loss: 0.021078210814569797
#     Eval loss: 0.11861503657118642
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 44 complete:
#     Train loss: 0.022758033155122617
#     Eval loss: 0.11791302089054066
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 45 complete:
#     Train loss: 0.023378045413156412
#     Eval loss: 0.11741290611939757
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 46 complete:
#     Train loss: 0.01952898016694025
#     Eval loss: 0.11836117863245516
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 47 complete:
#     Train loss: 0.02310121828508282
#     Eval loss: 0.1151997062511863
#
# Learning rate: [1.2800000000000007e-08]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 48 complete:
#     Train loss: 0.022993605808482295
#     Eval loss: 0.11671740793618293
#
# Learning rate: [1.2800000000000007e-08]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 49 complete:
#     Train loss: 0.022080464889266207
#     Eval loss: 0.11622146835502119
#
# Learning rate: [1.2800000000000007e-08]
# Peak GPU memory usage:
# 2.60608 GB
# Completed checkpoint at epoch: {ep}
# Completed training.
# Unloaded datasets.
# Unloaded datasets.

# %%
cnn_group.evaluate_subset(levels=[Names_of_Levels().detector_and_background], nums_events_per_set=[24_000,], remake_datasets=True)
# Out:
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_val.parquet
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_val.parquet
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Saved tensor of shape: torch.Size([6380, 1, 10, 10, 10]) to ..\state\data\images_det_bkg_q2v_resonances\24000_val_features.pt
# Saved tensor of shape: torch.Size([6380]) to ..\state\data\images_det_bkg_q2v_resonances\24000_val_labels.pt
# Made images dataset.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applying label subset.
# Applied label subset.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_val.parquet
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_val.parquet
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Saved tensor of shape: torch.Size([2000, 1, 10, 10, 10]) to ..\state\data\images_det_bkg_q2v_resonances\24000_val_sens_features.pt
# Saved tensor of shape: torch.Size([2000]) to ..\state\data\images_det_bkg_q2v_resonances\24000_val_sens_labels.pt
# Made images dataset.
# Loaded tensor of shape: torch.Size([6380, 1, 10, 10, 10]) from ..\state\data\images_det_bkg_q2v_resonances\24000_val_features.pt
# Loaded tensor of shape: torch.Size([6380]) from ..\state\data\images_det_bkg_q2v_resonances\24000_val_labels.pt
# Loaded tensor of shape: torch.Size([2000, 1, 10, 10, 10]) from ..\state\data\images_det_bkg_q2v_resonances\24000_val_sens_features.pt
# Loaded tensor of shape: torch.Size([2000]) from ..\state\data\images_det_bkg_q2v_resonances\24000_val_sens_labels.pt
# C:\Users\tetha\Desktop\btokstmumu-ml\common\logic\btokstmumu_ml_helpers\experiment\results_table.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   self.table.loc[
# Unloaded datasets.
# Unloaded datasets.

# %%
fig, axs = plt.subplots(3, 3, sharex=True, sharey=True, layout="compressed")

names_of_levels = {Names_of_Levels().generator : "Generator", Names_of_Levels().detector : "Detector", Names_of_Levels().detector_and_background : "Detector and Bkg."}

for (level, num_events_per_set), ax in zip(product(Names_of_Levels().tuple_, Numbers_of_Events_per_Set().tuple_), axs.flat):
    
    plot_linearity(
        linearity_test_results=cnn_group.results[level][num_events_per_set].linearity_results, 
        ax=ax,
    )

    ax.set_title(
        f"Level: {names_of_levels[level]}"
        f"\nEvents/set: {num_events_per_set}"
        "\n" + r"Sets/$\delta C_9$: " + f"{cnn_group.num_sets_per_label[num_events_per_set]}", 
        loc="left"
    )

axs.flat[0].legend()
# fig.suptitle(f"CNN, bins/dim.: {cnn_group.num_bins_per_dimension}\n", x=0.02, horizontalalignment="left")
fig.suptitle(f"CNN\n", x=0.02, horizontalalignment="left")
fig.supxlabel(r"Actual $\delta C_9$", fontsize=11, x=0.56, y=-0.06)
fig.supylabel(r"Predicted $\delta C_9$", fontsize=11, y=0.45)

plt.savefig(Paths_to_Directories().path_to_plots_dir.joinpath("cnn_grid_lin.png"), bbox_inches="tight")
plt.close()

# %%
plots_dir = Path("../state/plots")

names_of_levels = {Names_of_Levels().generator : "Generator", Names_of_Levels().detector : "Detector", Names_of_Levels().detector_and_background : "Detector and Bkg."}

fig, ax = plt.subplots()

level = Names_of_Levels().detector_and_background
num_events_per_set = 24_000

plot_linearity(
    linearity_test_results=cnn_group.results[level][num_events_per_set].linearity_results,
    ax=ax,
)

ax.set_title(
    f"Level: {names_of_levels[level]}"
    f"\nEvents/set: {num_events_per_set}"
    "\n" + r"Sets/$\delta C_9$: " + f"{cnn_group.num_sets_per_label[num_events_per_set]}", 
    loc="left"
)

ax.legend()

fig.suptitle(f"CNN\n", x=0.02, horizontalalignment="left")
ax.set_xlabel(r"Actual $\delta C_9$", fontsize=11)
ax.set_ylabel(r"Predicted $\delta C_9$", fontsize=11)

plt.savefig(plots_dir.joinpath(f"cnn_lin_{level}_{num_events_per_set}.png"), bbox_inches="tight")
plt.close()
