# %%
from btokstmumu_ml_helpers.datasets.constants import Names_of_Levels, Raw_Signal_Trial_Ranges
from btokstmumu_ml_helpers.datasets.make_and_save.aggregated_signal import Aggregated_Signal_Dataframe_Handler


for level in (Names_of_Levels().generator, Names_of_Levels().detector):

    for trial_range in Raw_Signal_Trial_Ranges().tuple_:
        
        Aggregated_Signal_Dataframe_Handler(
            path_to_common_processed_datasets_dir="../../common/state/data/processed",
            level=level,
            trial_range=trial_range
        ).make_and_save(path_to_raw_signal_dir="../../common/state/data/raw/signal", dtype="float32")
# Out:
# Obtained delta C9 value: -0.01 from file: ..\..\common\state\data\raw\signal\dc9_-0.01_10_re.pkl
# Obtained delta C9 value: -0.01 from file: ..\..\common\state\data\raw\signal\dc9_-0.01_11_re.pkl
# Obtained delta C9 value: -0.01 from file: ..\..\common\state\data\raw\signal\dc9_-0.01_12_re.pkl
# Obtained delta C9 value: -0.01 from file: ..\..\common\state\data\raw\signal\dc9_-0.01_13_re.pkl
# Obtained delta C9 value: -0.01 from file: ..\..\common\state\data\raw\signal\dc9_-0.01_14_re.pkl
# Obtained delta C9 value: -0.01 from file: ..\..\common\state\data\raw\signal\dc9_-0.01_15_re.pkl
# Obtained delta C9 value: -0.01 from file: ..\..\common\state\data\raw\signal\dc9_-0.01_16_re.pkl
# Obtained delta C9 value: -0.01 from file: ..\..\common\state\data\raw\signal\dc9_-0.01_17_re.pkl
# Obtained delta C9 value: -0.01 from file: ..\..\common\state\data\raw\signal\dc9_-0.01_18_re.pkl
# Obtained delta C9 value: -0.01 from file: ..\..\common\state\data\raw\signal\dc9_-0.01_19_re.pkl
# ...
