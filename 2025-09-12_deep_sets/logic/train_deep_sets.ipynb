# %% [markdown]
# Setup

# %%
from pathlib import Path
from itertools import product

from torch.nn import MSELoss, L1Loss
import matplotlib as mpl
import matplotlib.pyplot as plt

from btokstmumu_ml_helpers.datasets.constants import Names_of_Levels, Names_of_q_Squared_Vetos, Numbers_of_Signal_Events_per_Set
from btokstmumu_ml_helpers.experiment.experiment import CNN_Group
from btokstmumu_ml_helpers.experiment.results_table import Results_Table
from btokstmumu_ml_helpers.experiment.constants import Paths_to_Directories
from btokstmumu_ml_helpers.models.hardware_util import select_device
from btokstmumu_ml_helpers.plot.linearity import plot_linearity

results_table = Results_Table()
device = select_device()

mpl.rcParams["figure.figsize"] = (6, 4)
mpl.rcParams["figure.dpi"] = 400
mpl.rcParams["axes.titlesize"] = 8
mpl.rcParams["figure.titlesize"] = 8
mpl.rcParams["figure.labelsize"] = 30
mpl.rcParams["text.usetex"] = True
mpl.rcParams["text.latex.preamble"] = r"\usepackage{bm}"
mpl.rcParams["font.family"] = "serif"
mpl.rcParams["font.serif"] = ["Computer Modern"]
mpl.rcParams["font.size"] = 8
mpl.rcParams["axes.titley"] = None
mpl.rcParams["axes.titlepad"] = 2
mpl.rcParams["legend.fancybox"] = False
mpl.rcParams["legend.framealpha"] = 0
mpl.rcParams["legend.markerscale"] = 1
mpl.rcParams["legend.fontsize"] = 7.5
# Out:
# Device:  cuda

# %% [markdown]
# CNN

# %%
cnn_group = CNN_Group(
    model_variant="shawn",
    num_sets_per_label={8_000 : 400, 16_000 : 200, 32_000 : 100},
    num_sets_per_label_sensitivity=2000,
    num_bins_per_dimension=50, #nominal is 10, retrain det_bkg models with 50
    q_squared_veto=Names_of_q_Squared_Vetos().resonances,
    std_scale=True,
    shuffle=True,
    uniform_label_counts=True,
    loss_fn=MSELoss(), # nominal MSE loss
    learning_rate=1e-3, # nominal 3e-4
    learning_rate_scheduler_reduction_factor=0.2, # nominal 0.97
    learning_rate_scheduler_patience=5,
    size_of_training_batch={8_000 : 128, 16_000 : 64, 32_000 : 32},
    size_of_evaluation_batch={8_000 : 128, 16_000 : 64, 32_000 : 32},
    number_of_epochs=50, # nominal 100
    number_of_epochs_between_checkpoints=1,
    results_table=results_table,
    device=device,
    bkg_fraction=0.44,
    bkg_charge_fraction=0.57,
    path_to_common_processed_datasets_dir="../../common/state/data/processed",
    path_to_local_processed_datasets_dir="../state/data",
    path_to_local_models_dir="../state/models"
)

# %%
cnn_group.train_subset(
    levels=[Names_of_Levels().detector_and_background,], 
    nums_signal_events_per_set=(8_000, 16_000, 32_000), 
    remake_datasets=True
)
# Out:
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      170
# costheta_K       760
# chi              760
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Saved tensor of shape: torch.Size([17600, 1, 50, 50, 50]) to ..\state\data\images_det_bkg_q2v_resonances\8000_train_features.pt
# Saved tensor of shape: torch.Size([17600]) to ..\state\data\images_det_bkg_q2v_resonances\8000_train_labels.pt
# Made images dataset.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_val.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_val.parquet  dtype: float32
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Saved tensor of shape: torch.Size([17600, 1, 50, 50, 50]) to ..\state\data\images_det_bkg_q2v_resonances\8000_val_features.pt
# Saved tensor of shape: torch.Size([17600]) to ..\state\data\images_det_bkg_q2v_resonances\8000_val_labels.pt
# Made images dataset.
# Loaded tensor of shape: torch.Size([17600, 1, 50, 50, 50]) from ..\state\data\images_det_bkg_q2v_resonances\8000_train_features.pt
# Loaded tensor of shape: torch.Size([17600]) from ..\state\data\images_det_bkg_q2v_resonances\8000_train_labels.pt
# Loaded tensor of shape: torch.Size([17600, 1, 50, 50, 50]) from ..\state\data\images_det_bkg_q2v_resonances\8000_val_features.pt
# Loaded tensor of shape: torch.Size([17600]) from ..\state\data\images_det_bkg_q2v_resonances\8000_val_labels.pt
#
# Epoch 0 complete:
#     Train loss: 0.4265087842941284
#     Eval loss: 0.2672799527645111
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 1 complete:
#     Train loss: 0.06663194298744202
#     Eval loss: 0.3804362416267395
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 2 complete:
#     Train loss: 0.06295928359031677
#     Eval loss: 0.059197280555963516
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 3 complete:
#     Train loss: 0.056435905396938324
#     Eval loss: 0.5170509219169617
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 4 complete:
#     Train loss: 0.05175740271806717
#     Eval loss: 0.1661507487297058
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 5 complete:
#     Train loss: 0.05041259154677391
#     Eval loss: 0.29223281145095825
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 6 complete:
#     Train loss: 0.04711271449923515
#     Eval loss: 0.18814653158187866
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 7 complete:
#     Train loss: 0.03936212882399559
#     Eval loss: 0.1263394057750702
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 8 complete:
#     Train loss: 0
#
# Learning rate: [0.0002]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 18 complete:
#     Train loss: 0.03236888349056244
#     Eval loss: 0.09027741849422455
#
# Learning rate: [4e-05]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 19 complete:
#     Train loss: 0.022601455450057983
#     Eval loss: 0.07797923684120178
#
# Learning rate: [4e-05]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 20 complete:
#     Train loss: 0.023550864309072495
#     Eval loss: 0.07704585045576096
#
# Learning rate: [4e-05]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 21 complete:
#     Train loss: 0.022189615294337273
#     Eval loss: 0.13486012816429138
#
# Learning rate: [4e-05]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 22 complete:
#     Train loss: 0.021169500425457954
#     Eval loss: 0.24460949003696442
#
# Learning rate: [4e-05]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 23 complete:
#     Train loss: 0.02155974879860878
#     Eval loss: 0.03569706529378891
#
# Learning rate: [4e-05]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 24 complete:
#     Train loss: 0.01891864277422428
#     Eval loss: 0.04933974891901016
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 25 complete:
#     Train loss: 0.020955298095941544
#     Eval loss: 0.06450571119785309
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 26 complete:
#     Train loss: 0.020196763798594475
#     Eval loss: 0.08185029029846191
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 27 complete:
#     Train loss: 0.018286848440766335
#     Eval loss: 0.052903443574905396
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 28 complete:
#     Train loss: 0.01817786693572998
#     Eval loss: 0.04770601540803909
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 29 complete:
#     Train loss: 0.018650444224476814
#     Eval loss: 0.04837477207183838
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 30 complete:
#     Train loss: 0.020758746191859245
#     Eval loss: 0.06620953977108002
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 31 complete:
#     Train loss: 0.018076598644256592
#     Eval loss: 0.04944455996155739
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 32 complete:
#     Train loss: 0.01649210974574089
#     Eval loss: 0.0636742115020752
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 33 complete:
#     Train loss: 0.018861861899495125
#     Eval loss: 0.05698584020137787
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 34 complete:
#     Train loss: 0.017974790185689926
#     Eval loss: 0.0638323724269867
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 35 complete:
#     Train loss: 0.017789611592888832
#     Eval loss: 0.05562612786889076
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 36 complete:
#     Train loss: 0.017622489482164383
#     Eval loss: 0.05713267624378204
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 37 complete:
#     Train loss: 0.01998312398791313
#     Eval loss: 0.055450402200222015
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 38 complete:
#     Train loss: 0.017117908224463463
#     Eval loss: 0.06985436379909515
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 39 complete:
#     Train loss: 0.01897357404232025
#     Eval loss: 0.04834838584065437
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 40 complete:
#     Train loss: 0.017852332442998886
#     Eval loss: 0.05258166044950485
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 41 complete:
#     Train loss: 0.018824895843863487
#     Eval loss: 0.05157962813973427
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 42 complete:
#     Train loss: 0.01758427359163761
#     Eval loss: 0.04919000715017319
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 43 complete:
#     Train loss: 0.016701126471161842
#     Eval loss: 0.05005715787410736
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 44 complete:
#     Train loss: 0.018869325518608093
#     Eval loss: 0.05413300544023514
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 45 complete:
#     Train loss: 0.018222706392407417
#     Eval loss: 0.05391615256667137
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 46 complete:
#     Train loss: 0.018382390961050987
#     Eval loss: 0.05633725970983505
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 47 complete:
#     Train loss: 0.017727619037032127
#     Eval loss: 0.05664109066128731
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 48 complete:
#     Train loss: 0.018314393237233162
#     Eval loss: 0.07722701132297516
#
# Learning rate: [1.2800000000000007e-08]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 49 complete:
#     Train loss: 0.017847402021288872
#     Eval loss: 0.05939047783613205
#
# Learning rate: [1.2800000000000007e-08]
# Peak GPU memory usage:
# 2.91220 GB
# Completed checkpoint at epoch: {ep}
# Completed training.
# Unloaded datasets.
# Unloaded datasets.

# %%
cnn_group.evaluate_subset(
    levels=[Names_of_Levels().detector_and_background], 
    nums_signal_events_per_set=[8_000, 16_000, 32_000,], 
    remake_datasets=True
)
# Out:
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_val.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_val.parquet  dtype: float32
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Saved tensor of shape: torch.Size([17600, 1, 50, 50, 50]) to ..\state\data\images_det_bkg_q2v_resonances\8000_val_features.pt
# Saved tensor of shape: torch.Size([17600]) to ..\state\data\images_det_bkg_q2v_resonances\8000_val_labels.pt
# Made images dataset.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applying label subset.
# Applied label subset.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_val.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_val.parquet  dtype: float32
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Saved tensor of shape: torch.Size([2000, 1, 50, 50, 50]) to ..\state\data\images_det_bkg_q2v_resonances\8000_val_sens_features.pt
# Saved tensor of shape: torch.Size([2000]) to ..\state\data\images_det_bkg_q2v_resonances\8000_val_sens_labels.pt
# Made images dataset.
# Loaded tensor of shape: torch.Size([17600, 1, 50, 50, 50]) from ..\state\data\images_det_bkg_q2v_resonances\8000_val_features.pt
# Loaded tensor of shape: torch.Size([17600]) from ..\state\data\images_det_bkg_q2v_resonances\8000_val_labels.pt
# Loaded tensor of shape: torch.Size([2000, 1, 50, 50, 50]) from ..\state\data\images_det_bkg_q2v_resonances\8000_val_sens_features.pt
# Loaded tensor of shape: torch.Size([2000]) from ..\state\data\images_det_bkg_q2v_resonances\8000_val_sens_labels.pt
# C:\Users\tetha\Desktop\btokstmumu-ml\common\logic\btokstmumu_ml_helpers\experiment\results_table.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   self.table.loc[
# Unloaded datasets.
# Unloaded datasets.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_val.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_val.parquet  dtype: float32
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Saved tensor of shape: torch.Size([8800, 1, 50, 50, 50]) to ..\state\data\images_det_bkg_q2v_resonances\16000_val_features.pt
# Saved tensor of shape: torch.Size([8800]) to ..\state\data\images_det_bkg_q2v_resonances\16000_val_labels.pt
# Made images dataset.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applying label subset.
# Applied label subset.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_val.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_val.parquet  dtype: float32
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Saved tensor of shape: torch.Size([2000, 1, 50, 50, 50]) to ..\state\data\images_det_bkg_q2v_resonances\16000_val_sens_features.pt
# Saved tensor of shape: torch.Size([2000]) to ..\state\data\images_det_bkg_q2v_resonances\16000_val_sens_labels.pt
# Made images dataset.
# Loaded tensor of shape: torch.Size([8800, 1, 50, 50, 50]) from ..\state\data\images_det_bkg_q2v_resonances\16000_val_features.pt
# Loaded tensor of shape: torch.Size([8800]) from ..\state\data\images_det_bkg_q2v_resonances\16000_val_labels.pt
# Loaded tensor of shape: torch.Size([2000, 1, 50, 50, 50]) from ..\state\data\images_det_bkg_q2v_resonances\16000_val_sens_features.pt
# Loaded tensor of shape: torch.Size([2000]) from ..\state\data\images_det_bkg_q2v_resonances\16000_val_sens_labels.pt
# C:\Users\tetha\Desktop\btokstmumu-ml\common\logic\btokstmumu_ml_helpers\experiment\results_table.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   self.table.loc[
# Unloaded datasets.
# Unloaded datasets.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_val.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_val.parquet  dtype: float32
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Saved tensor of shape: torch.Size([4400, 1, 50, 50, 50]) to ..\state\data\images_det_bkg_q2v_resonances\32000_val_features.pt
# Saved tensor of shape: torch.Size([4400]) to ..\state\data\images_det_bkg_q2v_resonances\32000_val_labels.pt
# Made images dataset.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applying label subset.
# Applied label subset.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_val.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_val.parquet  dtype: float32
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Saved tensor of shape: torch.Size([2000, 1, 50, 50, 50]) to ..\state\data\images_det_bkg_q2v_resonances\32000_val_sens_features.pt
# Saved tensor of shape: torch.Size([2000]) to ..\state\data\images_det_bkg_q2v_resonances\32000_val_sens_labels.pt
# Made images dataset.
# Loaded tensor of shape: torch.Size([4400, 1, 50, 50, 50]) from ..\state\data\images_det_bkg_q2v_resonances\32000_val_features.pt
# Loaded tensor of shape: torch.Size([4400]) from ..\state\data\images_det_bkg_q2v_resonances\32000_val_labels.pt
# Loaded tensor of shape: torch.Size([2000, 1, 50, 50, 50]) from ..\state\data\images_det_bkg_q2v_resonances\32000_val_sens_features.pt
# Loaded tensor of shape: torch.Size([2000]) from ..\state\data\images_det_bkg_q2v_resonances\32000_val_sens_labels.pt
# C:\Users\tetha\Desktop\btokstmumu-ml\common\logic\btokstmumu_ml_helpers\experiment\results_table.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   self.table.loc[
# Unloaded datasets.
# Unloaded datasets.

# %%
cnn_group.train_subset(
    levels=[Names_of_Levels().generator, Names_of_Levels().detector], 
    nums_signal_events_per_set=(8_000, 16_000, 32_000), 
    remake_datasets=True
)

cnn_group.evaluate_subset(
    levels=[Names_of_Levels().generator, Names_of_Levels().detector], 
    nums_signal_events_per_set=[8_000, 16_000, 32_000,], 
    remake_datasets=True
)
# Out:
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared        0
# costheta_mu      0
# costheta_K       0
# chi              0
# dc9              0
# dc9_bin_index    0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Saved tensor of shape: torch.Size([17600, 1, 50, 50, 50]) to ..\state\data\images_gen_q2v_resonances\8000_train_features.pt
# Saved tensor of shape: torch.Size([17600]) to ..\state\data\images_gen_q2v_resonances\8000_train_labels.pt
# Made images dataset.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared        0
# costheta_mu      0
# costheta_K       0
# chi              0
# dc9              0
# dc9_bin_index    0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Saved tensor of shape: torch.Size([17600, 1, 50, 50, 50]) to ..\state\data\images_gen_q2v_resonances\8000_val_features.pt
# Saved tensor of shape: torch.Size([17600]) to ..\state\data\images_gen_q2v_resonances\8000_val_labels.pt
# Made images dataset.
# Loaded tensor of shape: torch.Size([17600, 1, 50, 50, 50]) from ..\state\data\images_gen_q2v_resonances\8000_train_features.pt
# Loaded tensor of shape: torch.Size([17600]) from ..\state\data\images_gen_q2v_resonances\8000_train_labels.pt
# Loaded tensor of shape: torch.Size([17600, 1, 50, 50, 50]) from ..\state\data\images_gen_q2v_resonances\8000_val_features.pt
# Loaded tensor of shape: torch.Size([17600]) from ..\state\data\images_gen_q2v_resonances\8000_val_labels.pt
#
# Epoch 0 complete:
#     Train loss: 0.4644938111305237
#     Eval loss: 0.0976673886179924
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 3.68339 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 1 complete:
#     Train loss: 0.05861456319689751
#     Eval loss: 0.04302627965807915
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 3.68339 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 2 complete:
#     Train loss: 0.05182282626628876
#     Eval loss: 0.1686255931854248
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 3.68339 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 3 complete:
#     Train loss: 0.0510651096701622
#     Eval loss: 0.3222334682941437
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 3.68339 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 4 complete:
#     Train loss: 0
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 9 complete:
#     Train loss: 0.03728557750582695
#     Eval loss: 1.7124077081680298
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 10 complete:
#     Train loss: 0.03810933604836464
#     Eval loss: 1.8442730903625488
#
# Learning rate: [0.0002]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 11 complete:
#     Train loss: 0.024666765704751015
#     Eval loss: 0.0709521546959877
#
# Learning rate: [0.0002]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 12 complete:
#     Train loss: 0.024374889209866524
#     Eval loss: 0.12164729833602905
#
# Learning rate: [0.0002]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 13 complete:
#     Train loss: 0.024159112945199013
#     Eval loss: 0.07095955312252045
#
# Learning rate: [0.0002]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 14 complete:
#     Train loss: 0.02276712842285633
#     Eval loss: 0.06852936744689941
#
# Learning rate: [0.0002]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 15 complete:
#     Train loss: 0.022774284705519676
#     Eval loss: 0.08944200724363327
#
# Learning rate: [0.0002]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 16 complete:
#     Train loss: 0.023072144016623497
#     Eval loss: 0.5997598171234131
#
# Learning rate: [4e-05]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 17 complete:
#     Train loss: 0.021938152611255646
#     Eval loss: 0.05845114216208458
#
# Learning rate: [4e-05]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 18 complete:
#     Train loss: 0.01921752467751503
#     Eval loss: 0.0723239853978157
#
# Learning rate: [4e-05]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 19 complete:
#     Train loss: 0.02051740325987339
#     Eval loss: 0.06745820492506027
#
# Learning rate: [4e-05]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 20 complete:
#     Train loss: 0.018569378182291985
#     Eval loss: 0.08090400695800781
#
# Learning rate: [4e-05]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 21 complete:
#     Train loss: 0.018375558778643608
#     Eval loss: 0.06964016705751419
#
# Learning rate: [4e-05]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 22 complete:
#     Train loss: 0.020696960389614105
#     Eval loss: 0.0754401758313179
#
# Learning rate: [4e-05]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 23 complete:
#     Train loss: 0.018225528299808502
#     Eval loss: 0.06041474640369415
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 24 complete:
#     Train loss: 0.018244700506329536
#     Eval loss: 0.060269955545663834
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 25 complete:
#     Train loss: 0.018726978451013565
#     Eval loss: 0.06095525622367859
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 26 complete:
#     Train loss: 0.0186504777520895
#     Eval loss: 0.06053668260574341
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 27 complete:
#     Train loss: 0.017921578139066696
#     Eval loss: 0.062313735485076904
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 28 complete:
#     Train loss: 0.01891421340405941
#     Eval loss: 0.06227615848183632
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 29 complete:
#     Train loss: 0.01879321038722992
#     Eval loss: 0.06215175613760948
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 30 complete:
#     Train loss: 0.01893446408212185
#     Eval loss: 0.060662150382995605
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 31 complete:
#     Train loss: 0.018453439697623253
#     Eval loss: 0.06092824786901474
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 32 complete:
#     Train loss: 0.017386741936206818
#     Eval loss: 0.059913892298936844
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 33 complete:
#     Train loss: 0.018627585843205452
#     Eval loss: 0.06060049682855606
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 34 complete:
#     Train loss: 0.018108561635017395
#     Eval loss: 0.06091691553592682
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 35 complete:
#     Train loss: 0.01775696501135826
#     Eval loss: 0.06074216216802597
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 36 complete:
#     Train loss: 0.018596883863210678
#     Eval loss: 0.060961611568927765
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 37 complete:
#     Train loss: 0.018910860642790794
#     Eval loss: 0.06109115853905678
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 38 complete:
#     Train loss: 0.01791006699204445
#     Eval loss: 0.06055080145597458
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 39 complete:
#     Train loss: 0.018112443387508392
#     Eval loss: 0.06118981912732124
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 40 complete:
#     Train loss: 0.01793239638209343
#     Eval loss: 0.06023264303803444
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 41 complete:
#     Train loss: 0.01913951337337494
#     Eval loss: 0.06078483909368515
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 42 complete:
#     Train loss: 0.017755327746272087
#     Eval loss: 0.061437737196683884
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 43 complete:
#     Train loss: 0.01764894835650921
#     Eval loss: 0.060855600982904434
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 44 complete:
#     Train loss: 0.01916634477674961
#     Eval loss: 0.06016356125473976
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 45 complete:
#     Train loss: 0.017935600131750107
#     Eval loss: 0.06054693087935448
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 46 complete:
#     Train loss: 0.01885446533560753
#     Eval loss: 0.06034103408455849
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 47 complete:
#     Train loss: 0.018272411078214645
#     Eval loss: 0.06052833050489426
#
# Learning rate: [1.2800000000000007e-08]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 48 complete:
#     Train loss: 0.01834346354007721
#     Eval loss: 0.060769978910684586
#
# Learning rate: [1.2800000000000007e-08]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 49 complete:
#     Train loss: 0.019040118902921677
#     Eval loss: 0.06135083734989166
#
# Learning rate: [1.2800000000000007e-08]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
# Completed training.
# Unloaded datasets.
# Unloaded datasets.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      170
# costheta_K       760
# chi              760
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# ...
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 42 complete:
#     Train loss: 0.018335221335291862
#     Eval loss: 0.03667266666889191
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 43 complete:
#     Train loss: 0.017770327627658844
#     Eval loss: 0.0337320901453495
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 44 complete:
#     Train loss: 0.01799454726278782
#     Eval loss: 0.03647515922784805
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 45 complete:
#     Train loss: 0.01752530038356781
#     Eval loss: 0.03701773285865784
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 46 complete:
#     Train loss: 0.018209213390946388
#     Eval loss: 0.031856365501880646
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 47 complete:
#     Train loss: 0.017283504828810692
#     Eval loss: 0.03647397831082344
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 48 complete:
#     Train loss: 0.017632653936743736
#     Eval loss: 0.0355084165930748
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 49 complete:
#     Train loss: 0.018512854352593422
#     Eval loss: 0.03334357216954231
#
# Learning rate: [1.2800000000000007e-08]
# Peak GPU memory usage:
# 4.44872 GB
# Completed checkpoint at epoch: {ep}
# Completed training.
# Unloaded datasets.
# Unloaded datasets.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared        0
# costheta_mu      0
# costheta_K       0
# chi              0
# dc9              0
# dc9_bin_index    0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Saved tensor of shape: torch.Size([17600, 1, 50, 50, 50]) to ..\state\data\images_gen_q2v_resonances\8000_val_features.pt
# Saved tensor of shape: torch.Size([17600]) to ..\state\data\images_gen_q2v_resonances\8000_val_labels.pt
# Made images dataset.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared        0
# costheta_mu      0
# costheta_K       0
# chi              0
# dc9              0
# dc9_bin_index    0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applying label subset.
# Applied label subset.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Saved tensor of shape: torch.Size([2000, 1, 50, 50, 50]) to ..\state\data\images_gen_q2v_resonances\8000_val_sens_features.pt
# Saved tensor of shape: torch.Size([2000]) to ..\state\data\images_gen_q2v_resonances\8000_val_sens_labels.pt
# Made images dataset.
# Loaded tensor of shape: torch.Size([17600, 1, 50, 50, 50]) from ..\state\data\images_gen_q2v_resonances\8000_val_features.pt
# Loaded tensor of shape: torch.Size([17600]) from ..\state\data\images_gen_q2v_resonances\8000_val_labels.pt
# Loaded tensor of shape: torch.Size([2000, 1, 50, 50, 50]) from ..\state\data\images_gen_q2v_resonances\8000_val_sens_features.pt
# Loaded tensor of shape: torch.Size([2000]) from ..\state\data\images_gen_q2v_resonances\8000_val_sens_labels.pt
# C:\Users\tetha\Desktop\btokstmumu-ml\common\logic\btokstmumu_ml_helpers\experiment\results_table.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   self.table.loc[
# Unloaded datasets.
# Unloaded datasets.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Saved tensor of shape: torch.Size([17600, 1, 50, 50, 50]) to ..\state\data\images_det_q2v_resonances\8000_val_features.pt
# Saved tensor of shape: torch.Size([17600]) to ..\state\data\images_det_q2v_resonances\8000_val_labels.pt
# Made images dataset.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applying label subset.
# Applied label subset.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Saved tensor of shape: torch.Size([2000, 1, 50, 50, 50]) to ..\state\data\images_det_q2v_resonances\8000_val_sens_features.pt
# Saved tensor of shape: torch.Size([2000]) to ..\state\data\images_det_q2v_resonances\8000_val_sens_labels.pt
# Made images dataset.
# Loaded tensor of shape: torch.Size([17600, 1, 50, 50, 50]) from ..\state\data\images_det_q2v_resonances\8000_val_features.pt
# Loaded tensor of shape: torch.Size([17600]) from ..\state\data\images_det_q2v_resonances\8000_val_labels.pt
# Loaded tensor of shape: torch.Size([2000, 1, 50, 50, 50]) from ..\state\data\images_det_q2v_resonances\8000_val_sens_features.pt
# Loaded tensor of shape: torch.Size([2000]) from ..\state\data\images_det_q2v_resonances\8000_val_sens_labels.pt
# C:\Users\tetha\Desktop\btokstmumu-ml\common\logic\btokstmumu_ml_helpers\experiment\results_table.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   self.table.loc[
# Unloaded datasets.
# Unloaded datasets.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared        0
# costheta_mu      0
# costheta_K       0
# chi              0
# dc9              0
# dc9_bin_index    0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Saved tensor of shape: torch.Size([8800, 1, 50, 50, 50]) to ..\state\data\images_gen_q2v_resonances\16000_val_features.pt
# Saved tensor of shape: torch.Size([8800]) to ..\state\data\images_gen_q2v_resonances\16000_val_labels.pt
# Made images dataset.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared        0
# costheta_mu      0
# costheta_K       0
# chi              0
# dc9              0
# dc9_bin_index    0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applying label subset.
# Applied label subset.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Saved tensor of shape: torch.Size([2000, 1, 50, 50, 50]) to ..\state\data\images_gen_q2v_resonances\16000_val_sens_features.pt
# Saved tensor of shape: torch.Size([2000]) to ..\state\data\images_gen_q2v_resonances\16000_val_sens_labels.pt
# Made images dataset.
# Loaded tensor of shape: torch.Size([8800, 1, 50, 50, 50]) from ..\state\data\images_gen_q2v_resonances\16000_val_features.pt
# Loaded tensor of shape: torch.Size([8800]) from ..\state\data\images_gen_q2v_resonances\16000_val_labels.pt
# Loaded tensor of shape: torch.Size([2000, 1, 50, 50, 50]) from ..\state\data\images_gen_q2v_resonances\16000_val_sens_features.pt
# Loaded tensor of shape: torch.Size([2000]) from ..\state\data\images_gen_q2v_resonances\16000_val_sens_labels.pt
# C:\Users\tetha\Desktop\btokstmumu-ml\common\logic\btokstmumu_ml_helpers\experiment\results_table.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   self.table.loc[
# Unloaded datasets.
# Unloaded datasets.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Saved tensor of shape: torch.Size([8800, 1, 50, 50, 50]) to ..\state\data\images_det_q2v_resonances\16000_val_features.pt
# Saved tensor of shape: torch.Size([8800]) to ..\state\data\images_det_q2v_resonances\16000_val_labels.pt
# Made images dataset.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applying label subset.
# Applied label subset.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Saved tensor of shape: torch.Size([2000, 1, 50, 50, 50]) to ..\state\data\images_det_q2v_resonances\16000_val_sens_features.pt
# Saved tensor of shape: torch.Size([2000]) to ..\state\data\images_det_q2v_resonances\16000_val_sens_labels.pt
# Made images dataset.
# Loaded tensor of shape: torch.Size([8800, 1, 50, 50, 50]) from ..\state\data\images_det_q2v_resonances\16000_val_features.pt
# Loaded tensor of shape: torch.Size([8800]) from ..\state\data\images_det_q2v_resonances\16000_val_labels.pt
# Loaded tensor of shape: torch.Size([2000, 1, 50, 50, 50]) from ..\state\data\images_det_q2v_resonances\16000_val_sens_features.pt
# Loaded tensor of shape: torch.Size([2000]) from ..\state\data\images_det_q2v_resonances\16000_val_sens_labels.pt
# C:\Users\tetha\Desktop\btokstmumu-ml\common\logic\btokstmumu_ml_helpers\experiment\results_table.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   self.table.loc[
# Unloaded datasets.
# Unloaded datasets.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared        0
# costheta_mu      0
# costheta_K       0
# chi              0
# dc9              0
# dc9_bin_index    0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Saved tensor of shape: torch.Size([4400, 1, 50, 50, 50]) to ..\state\data\images_gen_q2v_resonances\32000_val_features.pt
# Saved tensor of shape: torch.Size([4400]) to ..\state\data\images_gen_q2v_resonances\32000_val_labels.pt
# Made images dataset.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared        0
# costheta_mu      0
# costheta_K       0
# chi              0
# dc9              0
# dc9_bin_index    0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applying label subset.
# Applied label subset.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Saved tensor of shape: torch.Size([2000, 1, 50, 50, 50]) to ..\state\data\images_gen_q2v_resonances\32000_val_sens_features.pt
# Saved tensor of shape: torch.Size([2000]) to ..\state\data\images_gen_q2v_resonances\32000_val_sens_labels.pt
# Made images dataset.
# Loaded tensor of shape: torch.Size([4400, 1, 50, 50, 50]) from ..\state\data\images_gen_q2v_resonances\32000_val_features.pt
# Loaded tensor of shape: torch.Size([4400]) from ..\state\data\images_gen_q2v_resonances\32000_val_labels.pt
# Loaded tensor of shape: torch.Size([2000, 1, 50, 50, 50]) from ..\state\data\images_gen_q2v_resonances\32000_val_sens_features.pt
# Loaded tensor of shape: torch.Size([2000]) from ..\state\data\images_gen_q2v_resonances\32000_val_sens_labels.pt
# C:\Users\tetha\Desktop\btokstmumu-ml\common\logic\btokstmumu_ml_helpers\experiment\results_table.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   self.table.loc[
# Unloaded datasets.
# Unloaded datasets.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Saved tensor of shape: torch.Size([4400, 1, 50, 50, 50]) to ..\state\data\images_det_q2v_resonances\32000_val_features.pt
# Saved tensor of shape: torch.Size([4400]) to ..\state\data\images_det_q2v_resonances\32000_val_labels.pt
# Made images dataset.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applying label subset.
# Applied label subset.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Saved tensor of shape: torch.Size([2000, 1, 50, 50, 50]) to ..\state\data\images_det_q2v_resonances\32000_val_sens_features.pt
# Saved tensor of shape: torch.Size([2000]) to ..\state\data\images_det_q2v_resonances\32000_val_sens_labels.pt
# Made images dataset.
# Loaded tensor of shape: torch.Size([4400, 1, 50, 50, 50]) from ..\state\data\images_det_q2v_resonances\32000_val_features.pt
# Loaded tensor of shape: torch.Size([4400]) from ..\state\data\images_det_q2v_resonances\32000_val_labels.pt
# Loaded tensor of shape: torch.Size([2000, 1, 50, 50, 50]) from ..\state\data\images_det_q2v_resonances\32000_val_sens_features.pt
# Loaded tensor of shape: torch.Size([2000]) from ..\state\data\images_det_q2v_resonances\32000_val_sens_labels.pt
# C:\Users\tetha\Desktop\btokstmumu-ml\common\logic\btokstmumu_ml_helpers\experiment\results_table.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   self.table.loc[
# Unloaded datasets.
# Unloaded datasets.

# %%
plots_dir = Path("../state/plots")

fig, axs = plt.subplots(3, 3, sharex=True, sharey=True, layout="compressed")

names_of_levels = {Names_of_Levels().generator : "Generator", Names_of_Levels().detector : "Detector", Names_of_Levels().detector_and_background : "Detector and Bkg."}

for (level, num_signal_events_per_set), ax in zip(product(Names_of_Levels().tuple_, Numbers_of_Signal_Events_per_Set().tuple_), axs.flat):
    
    plot_linearity(
        linearity_test_results=cnn_group.results[level][num_signal_events_per_set].linearity_results, 
        ax=ax,
    )

    ax.set_title(
        f"Level: {names_of_levels[level]}"
        f"\nEvents/set: {num_signal_events_per_set}"
        "\n" + r"Sets/$\delta C_9$: " + f"{cnn_group.num_sets_per_label[num_signal_events_per_set]}", 
        loc="left"
    )

axs.flat[0].legend()
# fig.suptitle(f"CNN, bins/dim.: {cnn_group.num_bins_per_dimension}\n", x=0.02, horizontalalignment="left")
fig.suptitle(f"CNN\n", x=0.02, horizontalalignment="left")
fig.supxlabel(r"Actual $\delta C_9$", fontsize=11, x=0.56, y=-0.06)
fig.supylabel(r"Predicted $\delta C_9$", fontsize=11, y=0.45)

plt.savefig(plots_dir.joinpath("cnn_grid_lin.png"), bbox_inches="tight")
plt.close()

# %%
plots_dir = Path("../state/plots")

names_of_levels = {Names_of_Levels().generator : "Generator", Names_of_Levels().detector : "Detector", Names_of_Levels().detector_and_background : "Detector and Bkg."}


level = Names_of_Levels().detector_and_background

nums_signal_events_per_set = (8_000, 16_000, 32_000,)

for num_signal_events_per_set in nums_signal_events_per_set:

    fig, ax = plt.subplots()
    
    plot_linearity(
        linearity_test_results=cnn_group.results[level][num_signal_events_per_set].linearity_results,
        ax=ax,
    )

    ax.set_title(
        f"Level: {names_of_levels[level]}"
        f"\nSignal events/set: {num_signal_events_per_set}"
        "\n" + r"Sets/$\delta C_9$: " + f"{cnn_group.num_sets_per_label[num_signal_events_per_set]}", 
        loc="left"
    )

    ax.legend()

    fig.suptitle(f"CNN\n", x=0.02, horizontalalignment="left")
    ax.set_xlabel(r"Actual $\delta C_9$", fontsize=11)
    ax.set_ylabel(r"Predicted $\delta C_9$", fontsize=11)

    plt.savefig(plots_dir.joinpath(f"cnn_lin_{level}_{num_signal_events_per_set}.png"), bbox_inches="tight")
    plt.close()
