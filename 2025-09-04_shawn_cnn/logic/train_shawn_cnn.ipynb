# %% [markdown]
# Setup

# %%
from pathlib import Path
from itertools import product

from torch.nn import MSELoss, L1Loss
import matplotlib as mpl
import matplotlib.pyplot as plt

from btokstmumu_ml_helpers.datasets.constants import Names_of_Levels, Names_of_q_Squared_Vetos, Numbers_of_Signal_Events_per_Set
from btokstmumu_ml_helpers.experiment.experiment import CNN_Group
from btokstmumu_ml_helpers.experiment.results_table import Results_Table
from btokstmumu_ml_helpers.experiment.constants import Paths_to_Directories
from btokstmumu_ml_helpers.models.hardware_util import select_device
from btokstmumu_ml_helpers.plot.linearity import plot_linearity

results_table = Results_Table()
device = select_device()

mpl.rcParams["figure.figsize"] = (6, 4)
mpl.rcParams["figure.dpi"] = 400
mpl.rcParams["axes.titlesize"] = 8
mpl.rcParams["figure.titlesize"] = 8
mpl.rcParams["figure.labelsize"] = 30
mpl.rcParams["text.usetex"] = True
mpl.rcParams["text.latex.preamble"] = r"\usepackage{bm}"
mpl.rcParams["font.family"] = "serif"
mpl.rcParams["font.serif"] = ["Computer Modern"]
mpl.rcParams["font.size"] = 8
mpl.rcParams["axes.titley"] = None
mpl.rcParams["axes.titlepad"] = 2
mpl.rcParams["legend.fancybox"] = False
mpl.rcParams["legend.framealpha"] = 0
mpl.rcParams["legend.markerscale"] = 1
mpl.rcParams["legend.fontsize"] = 7.5
# Out:
# Device:  cuda

# %% [markdown]
# CNN

# %%
cnn_group = CNN_Group(
    model_variant="shawn",
    num_sets_per_label={6_000 : 583, 24_000 : 145, 70_000 : 50},
    num_sets_per_label_sensitivity=2_000,
    num_bins_per_dimension=50, #nominal is 10, retrain det_bkg models with 50
    q_squared_veto=Names_of_q_Squared_Vetos().resonances,
    std_scale=True,
    shuffle=True,
    uniform_label_counts=True,
    loss_fn=MSELoss(), # nominal MSE loss
    learning_rate=1e-3, # nominal 3e-4
    learning_rate_scheduler_reduction_factor=0.2, # nominal 0.97
    learning_rate_scheduler_patience=5,
    size_of_training_batch={6_000 : 373, 24_000 : 93, 70_000 : 32},
    size_of_evaluation_batch={6_000 : 373, 24_000 : 93, 70_000 : 32},
    number_of_epochs=50, # nominal 100
    number_of_epochs_between_checkpoints=1,
    results_table=results_table,
    device=device,
    bkg_fraction=0.44,
    bkg_charge_fraction=0.57,
    path_to_common_processed_datasets_dir="../../common/state/data/processed",
    path_to_local_processed_datasets_dir="../state/data",
    path_to_local_models_dir="../state/models"
)

# %%
cnn_group.train_subset(
    levels=[Names_of_Levels().detector_and_background,], 
    nums_signal_events_per_set=(6_000, 24_000, 70_000), 
    remake_datasets=True
)
# Out:
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      170
# costheta_K       760
# chi              760
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Saved tensor of shape: torch.Size([25652, 1, 50, 50, 50]) to ..\state\data\images_det_bkg_q2v_resonances\6000_train_features.pt
# Saved tensor of shape: torch.Size([25652]) to ..\state\data\images_det_bkg_q2v_resonances\6000_train_labels.pt
# Made images dataset.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_val.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_val.parquet  dtype: float32
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Saved tensor of shape: torch.Size([25652, 1, 50, 50, 50]) to ..\state\data\images_det_bkg_q2v_resonances\6000_val_features.pt
# Saved tensor of shape: torch.Size([25652]) to ..\state\data\images_det_bkg_q2v_resonances\6000_val_labels.pt
# Made images dataset.
# Loaded tensor of shape: torch.Size([25652, 1, 50, 50, 50]) from ..\state\data\images_det_bkg_q2v_resonances\6000_train_features.pt
# Loaded tensor of shape: torch.Size([25652]) from ..\state\data\images_det_bkg_q2v_resonances\6000_train_labels.pt
# Loaded tensor of shape: torch.Size([25652, 1, 50, 50, 50]) from ..\state\data\images_det_bkg_q2v_resonances\6000_val_features.pt
# Loaded tensor of shape: torch.Size([25652]) from ..\state\data\images_det_bkg_q2v_resonances\6000_val_labels.pt
#
# Epoch 0 complete:
#     Train loss: 1.162115454673767
#     Eval loss: 2.2344400882720947
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 1 complete:
#     Train loss: 0.09159713238477707
#     Eval loss: 0.16337527334690094
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 2 complete:
#     Train loss: 0.07185911387205124
#     Eval loss: 0.16107504069805145
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 3 complete:
#     Train loss: 0.06354372948408127
#     Eval loss: 0.5086134076118469
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 4 complete:
#     Train loss: 0.06129886955022812
#     Eval loss: 0.4279710054397583
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 5 complete:
#     Train loss: 0.055580925196409225
#     Eval loss: 0.10165924578905106
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 6 complete:
#     Train loss: 0.05044928938150406
#     Eval loss: 1.4903861284255981
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 7 complete:
#     Train loss: 0.04574532061815262
#     Eval loss: 0.15272089838981628
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 8 complete:
#     Train loss: 0.042007870972156525
#     Eval loss: 0.12103134393692017
#
# Learning rate: [0.001]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 9 complete:
#     Train loss: 0
#
# Learning rate: [4e-05]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 26 complete:
#     Train loss: 0.021357279270887375
#     Eval loss: 0.05630511790513992
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 27 complete:
#     Train loss: 0.01968381367623806
#     Eval loss: 0.0677870512008667
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 28 complete:
#     Train loss: 0.022090356796979904
#     Eval loss: 0.03904154151678085
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 29 complete:
#     Train loss: 0.02590438723564148
#     Eval loss: 0.053346749395132065
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 30 complete:
#     Train loss: 0.021296385675668716
#     Eval loss: 0.048586003482341766
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 31 complete:
#     Train loss: 0.01930815912783146
#     Eval loss: 0.05544264614582062
#
# Learning rate: [8.000000000000001e-06]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 32 complete:
#     Train loss: 0.020363684743642807
#     Eval loss: 0.05781787261366844
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 33 complete:
#     Train loss: 0.01901439018547535
#     Eval loss: 0.059034936130046844
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 34 complete:
#     Train loss: 0.022157927975058556
#     Eval loss: 0.052117787301540375
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 35 complete:
#     Train loss: 0.02231684885919094
#     Eval loss: 0.053198859095573425
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 36 complete:
#     Train loss: 0.02079695463180542
#     Eval loss: 0.05832459405064583
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 37 complete:
#     Train loss: 0.02407706342637539
#     Eval loss: 0.06307443231344223
#
# Learning rate: [1.6000000000000004e-06]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 38 complete:
#     Train loss: 0.02307785302400589
#     Eval loss: 0.04719529673457146
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 39 complete:
#     Train loss: 0.01909126527607441
#     Eval loss: 0.05953335016965866
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 40 complete:
#     Train loss: 0.028880897909402847
#     Eval loss: 0.06366102397441864
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 41 complete:
#     Train loss: 0.018986079841852188
#     Eval loss: 0.06159656122326851
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 42 complete:
#     Train loss: 0.023339901119470596
#     Eval loss: 0.048627495765686035
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 43 complete:
#     Train loss: 0.020269624888896942
#     Eval loss: 0.04686722531914711
#
# Learning rate: [3.200000000000001e-07]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 44 complete:
#     Train loss: 0.023064572364091873
#     Eval loss: 0.050562888383865356
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 45 complete:
#     Train loss: 0.02061767876148224
#     Eval loss: 0.03976689279079437
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 46 complete:
#     Train loss: 0.022625671699643135
#     Eval loss: 0.05676773190498352
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 47 complete:
#     Train loss: 0.024353673681616783
#     Eval loss: 0.052591677755117416
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 48 complete:
#     Train loss: 0.020142432302236557
#     Eval loss: 0.04196060448884964
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
#
# Epoch 49 complete:
#     Train loss: 0.023616252467036247
#     Eval loss: 0.059051308780908585
#
# Learning rate: [6.400000000000003e-08]
# Peak GPU memory usage:
# 6.73493 GB
# Completed checkpoint at epoch: {ep}
# Completed training.
# Unloaded datasets.
# Unloaded datasets.

# %%
cnn_group.evaluate_subset(
    levels=[Names_of_Levels().detector_and_background], 
    nums_signal_events_per_set=[6_000, 24_000, 70_000], 
    remake_datasets=True
)
# Out:
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_val.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_val.parquet  dtype: float32
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Saved tensor of shape: torch.Size([25652, 1, 50, 50, 50]) to ..\state\data\images_det_bkg_q2v_resonances\6000_val_features.pt
# Saved tensor of shape: torch.Size([25652]) to ..\state\data\images_det_bkg_q2v_resonances\6000_val_labels.pt
# Made images dataset.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applying label subset.
# Applied label subset.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_val.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_val.parquet  dtype: float32
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Saved tensor of shape: torch.Size([2000, 1, 50, 50, 50]) to ..\state\data\images_det_bkg_q2v_resonances\6000_val_sens_features.pt
# Saved tensor of shape: torch.Size([2000]) to ..\state\data\images_det_bkg_q2v_resonances\6000_val_sens_labels.pt
# Made images dataset.
# Loaded tensor of shape: torch.Size([25652, 1, 50, 50, 50]) from ..\state\data\images_det_bkg_q2v_resonances\6000_val_features.pt
# Loaded tensor of shape: torch.Size([25652]) from ..\state\data\images_det_bkg_q2v_resonances\6000_val_labels.pt
# Loaded tensor of shape: torch.Size([2000, 1, 50, 50, 50]) from ..\state\data\images_det_bkg_q2v_resonances\6000_val_sens_features.pt
# Loaded tensor of shape: torch.Size([2000]) from ..\state\data\images_det_bkg_q2v_resonances\6000_val_sens_labels.pt
# C:\Users\tetha\Desktop\btokstmumu-ml\common\logic\btokstmumu_ml_helpers\experiment\results_table.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   self.table.loc[
# Unloaded datasets.
# Unloaded datasets.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_val.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_val.parquet  dtype: float32
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Saved tensor of shape: torch.Size([6380, 1, 50, 50, 50]) to ..\state\data\images_det_bkg_q2v_resonances\24000_val_features.pt
# Saved tensor of shape: torch.Size([6380]) to ..\state\data\images_det_bkg_q2v_resonances\24000_val_labels.pt
# Made images dataset.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applying label subset.
# Applied label subset.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_val.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_val.parquet  dtype: float32
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Saved tensor of shape: torch.Size([2000, 1, 50, 50, 50]) to ..\state\data\images_det_bkg_q2v_resonances\24000_val_sens_features.pt
# Saved tensor of shape: torch.Size([2000]) to ..\state\data\images_det_bkg_q2v_resonances\24000_val_sens_labels.pt
# Made images dataset.
# Loaded tensor of shape: torch.Size([6380, 1, 50, 50, 50]) from ..\state\data\images_det_bkg_q2v_resonances\24000_val_features.pt
# Loaded tensor of shape: torch.Size([6380]) from ..\state\data\images_det_bkg_q2v_resonances\24000_val_labels.pt
# Loaded tensor of shape: torch.Size([2000, 1, 50, 50, 50]) from ..\state\data\images_det_bkg_q2v_resonances\24000_val_sens_features.pt
# Loaded tensor of shape: torch.Size([2000]) from ..\state\data\images_det_bkg_q2v_resonances\24000_val_sens_labels.pt
# C:\Users\tetha\Desktop\btokstmumu-ml\common\logic\btokstmumu_ml_helpers\experiment\results_table.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   self.table.loc[
# Unloaded datasets.
# Unloaded datasets.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_val.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_val.parquet  dtype: float32
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Saved tensor of shape: torch.Size([2200, 1, 50, 50, 50]) to ..\state\data\images_det_bkg_q2v_resonances\70000_val_features.pt
# Saved tensor of shape: torch.Size([2200]) to ..\state\data\images_det_bkg_q2v_resonances\70000_val_labels.pt
# Made images dataset.
# Making images dataset.
# Applying signal preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared          0
# costheta_mu      168
# costheta_K       706
# chi              706
# dc9                0
# dc9_bin_index      0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applying label subset.
# Applied label subset.
# Reducing events per label to lowest per label.
# Shuffled dataframe.
# Reduced events per label to lowest per label.
# Applied signal preprocessing.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_val.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_val.parquet  dtype: float32
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Applying background preprocessing.
# Removing rows that have a NaN.
# Number of NA values:
#  q_squared      0
# costheta_mu    0
# costheta_K     0
# chi            0
# dtype: int64
# Removed rows that have a NaN.
# Applying q^2 veto.
# Applied q^2 veto.
# Applying standand scale.
# Applying q^2 veto.
# Applied q^2 veto.
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\charge_sb_bkg_train.parquet  dtype: float32
# Loaded background file: ..\..\common\state\data\processed\aggregated_generic\mix_sb_bkg_train.parquet  dtype: float32
# Applying q^2 veto.
# Applied q^2 veto.
# Applying q^2 veto.
# Applied q^2 veto.
# Applied standard scale.
# Shuffled dataframe.
# Applied background preprocessing.
# Saved tensor of shape: torch.Size([2000, 1, 50, 50, 50]) to ..\state\data\images_det_bkg_q2v_resonances\70000_val_sens_features.pt
# Saved tensor of shape: torch.Size([2000]) to ..\state\data\images_det_bkg_q2v_resonances\70000_val_sens_labels.pt
# Made images dataset.
# Loaded tensor of shape: torch.Size([2200, 1, 50, 50, 50]) from ..\state\data\images_det_bkg_q2v_resonances\70000_val_features.pt
# Loaded tensor of shape: torch.Size([2200]) from ..\state\data\images_det_bkg_q2v_resonances\70000_val_labels.pt
# Loaded tensor of shape: torch.Size([2000, 1, 50, 50, 50]) from ..\state\data\images_det_bkg_q2v_resonances\70000_val_sens_features.pt
# Loaded tensor of shape: torch.Size([2000]) from ..\state\data\images_det_bkg_q2v_resonances\70000_val_sens_labels.pt
# C:\Users\tetha\Desktop\btokstmumu-ml\common\logic\btokstmumu_ml_helpers\experiment\results_table.py:49: PerformanceWarning: indexing past lexsort depth may impact performance.
#   self.table.loc[
# Unloaded datasets.
# Unloaded datasets.

# %%
fig, axs = plt.subplots(3, 3, sharex=True, sharey=True, layout="compressed")

names_of_levels = {Names_of_Levels().generator : "Generator", Names_of_Levels().detector : "Detector", Names_of_Levels().detector_and_background : "Detector and Bkg."}

for (level, num_events_per_set), ax in zip(product(Names_of_Levels().tuple_, Numbers_of_Events_per_Set().tuple_), axs.flat):
    
    plot_linearity(
        linearity_test_results=cnn_group.results[level][num_events_per_set].linearity_results, 
        ax=ax,
    )

    ax.set_title(
        f"Level: {names_of_levels[level]}"
        f"\nEvents/set: {num_events_per_set}"
        "\n" + r"Sets/$\delta C_9$: " + f"{cnn_group.num_sets_per_label[num_events_per_set]}", 
        loc="left"
    )

axs.flat[0].legend()
# fig.suptitle(f"CNN, bins/dim.: {cnn_group.num_bins_per_dimension}\n", x=0.02, horizontalalignment="left")
fig.suptitle(f"CNN\n", x=0.02, horizontalalignment="left")
fig.supxlabel(r"Actual $\delta C_9$", fontsize=11, x=0.56, y=-0.06)
fig.supylabel(r"Predicted $\delta C_9$", fontsize=11, y=0.45)

plt.savefig(Paths_to_Directories().path_to_plots_dir.joinpath("cnn_grid_lin.png"), bbox_inches="tight")
plt.close()

# %%
plots_dir = Path("../state/plots")

names_of_levels = {Names_of_Levels().generator : "Generator", Names_of_Levels().detector : "Detector", Names_of_Levels().detector_and_background : "Detector and Bkg."}

fig, ax = plt.subplots()

level = Names_of_Levels().detector_and_background
num_events_per_set = 70_000

plot_linearity(
    linearity_test_results=cnn_group.results[level][num_events_per_set].linearity_results,
    ax=ax,
)

ax.set_title(
    f"Level: {names_of_levels[level]}"
    f"\nSignal events/set: {num_events_per_set}"
    "\n" + r"Sets/$\delta C_9$: " + f"{cnn_group.num_sets_per_label[num_events_per_set]}", 
    loc="left"
)

ax.legend()

fig.suptitle(f"CNN\n", x=0.02, horizontalalignment="left")
ax.set_xlabel(r"Actual $\delta C_9$", fontsize=11)
ax.set_ylabel(r"Predicted $\delta C_9$", fontsize=11)

plt.savefig(plots_dir.joinpath(f"cnn_lin_{level}_{num_events_per_set}.png"), bbox_inches="tight")
plt.close()
